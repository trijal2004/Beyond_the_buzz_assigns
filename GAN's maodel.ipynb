# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch.nn.functional as F

# %%
num_workers = 0
 
batch_size = 64

transform = transforms.ToTensor()

train_data = datasets.MNIST(root='data', train=True,
 download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
 num_workers=num_workers)
print(type(train_loader))
# Out:
# <class 'torch.utils.data.dataloader.DataLoader'>

# %%
num_samples = 10
fig, axes = plt.subplots(1, num_samples, figsize=(12, 2))

for i in range(num_samples):
    # Get a random image and its corresponding label
    index = torch.randint(len(train_data), size=(1,)).item()
    image, label = train_data[index]
    image = image.squeeze().numpy()

    # Display the image
    axes[i].imshow(image, cmap="gray")
    axes[i].set_title(f"Label: {label}")
    axes[i].axis("off")

plt.tight_layout()
plt.show()

# %%
class Discriminator(nn.Module):
   def __init__(self, input_size, hidden_dim, output_size):
     super(Discriminator, self).__init__()
 
 
     self.fc1 = nn.Linear(input_size, hidden_dim*4)
     self.fc2 = nn.Linear(hidden_dim*4, hidden_dim*2)
     self.fc3 = nn.Linear(hidden_dim*2, hidden_dim)
 
 
     self.fc4 = nn.Linear(hidden_dim, output_size)
 
   
     self.dropout = nn.Dropout(0.3)
 
 
   def forward(self, x):
  
     x = x.view(-1, 28*28)
 
     x = F.leaky_relu(self.fc1(x), 0.2) # (input, negative_slope=0.2)
     x = self.dropout(x)
     x = F.leaky_relu(self.fc2(x), 0.2)
     x = self.dropout(x)
     x = F.leaky_relu(self.fc3(x), 0.2)
     x = self.dropout(x)

     out = self.fc4(x)
     return out

# %%
class Generator(nn.Module):
  def __init__(self, input_size, hidden_dim, output_size):
    super(Generator, self).__init__()
 
 
    self.fc1 = nn.Linear(input_size, hidden_dim)
    self.fc2 = nn.Linear(hidden_dim, hidden_dim*2)
    self.fc3 = nn.Linear(hidden_dim*2, hidden_dim*4)
 
 
    self.fc4 = nn.Linear(hidden_dim*4, output_size)
 
 
    self.dropout = nn.Dropout(0.3)
  def forward(self, x):
  
   x = F.leaky_relu(self.fc1(x), 0.2) # (input, negative_slope=0.2)
   x = self.dropout(x)
   x = F.leaky_relu(self.fc2(x), 0.2)
   x = self.dropout(x)
   x = F.leaky_relu(self.fc3(x), 0.2)
   x = self.dropout(x)
   out = F.tanh(self.fc4(x))
   return out

# %%
 
input_size = 784 
d_output_size = 1
 
d_hidden_size = 32

 
z_size = 100
 
g_output_size = 784
 
g_hidden_size = 32

# %%
D = Discriminator(784, 32, 1)
G = Generator(100,32,784)
print(D)
print(G)
# Out:
# Discriminator(
#   (fc1): Linear(in_features=784, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=32, bias=True)
#   (fc4): Linear(in_features=32, out_features=1, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
# )
# Generator(
#   (fc1): Linear(in_features=100, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=784, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
# )

# %%
def real_loss(D_out, smooth=False):
 batch_size = D_out.size(0)
 
 if smooth:
   labels = torch.ones(batch_size)*0.9
 else:
   labels = torch.ones(batch_size) 
 
 
 criterion = nn.BCEWithLogitsLoss()

 loss = criterion(D_out.squeeze(), labels)
 return loss

def fake_loss(D_out):
 batch_size = D_out.size(0)
 labels = torch.zeros(batch_size) 
 criterion = nn.BCEWithLogitsLoss()

 loss = criterion(D_out.squeeze(), labels)
 return loss

# %%
import torch.optim as optim
lr = 0.002
d_optimizer = optim.Adam(D.parameters(), lr)
g_optimizer = optim.Adam(G.parameters(), lr)

# %% [markdown]
# FINAL TRAINING PROCESS

# %%
import pickle as pkl

 
num_epochs = 100

 
samples = []
losses = []

print_every = 400

 
sample_size=16
fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
fixed_z = torch.from_numpy(fixed_z).float()

 
D.train()
G.train()
for epoch in range(num_epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
                
        batch_size = real_images.size(0)
        
        
        real_images = real_images*2 - 1  
        d_optimizer.zero_grad()
        
        
        D_real = D(real_images)
        d_real_loss = real_loss(D_real, smooth=True)
        
         
        z = np.random.uniform(-1, 1, size=(batch_size, z_size))
        z = torch.from_numpy(z).float()
        fake_images = G(z)
        
       
        D_fake = D(fake_images)
        d_fake_loss = fake_loss(D_fake)
         
        d_loss = d_real_loss + d_fake_loss
        d_loss.backward()
        d_optimizer.step()
        g_optimizer.zero_grad()
        
 
     
        z = np.random.uniform(-1, 1, size=(batch_size, z_size))
        z = torch.from_numpy(z).float()
        fake_images = G(z)
        
     
        D_fake = D(fake_images)
        g_loss = real_loss(D_fake) 
         
        g_loss.backward()
        g_optimizer.step()

        
        if batch_i % print_every == 0:
          
            print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                    epoch+1, num_epochs, d_loss.item(), g_loss.item()))
           
    losses.append((d_loss.item(), g_loss.item()))
    
     
    G.eval()  
    samples_z = G(fixed_z)
    samples.append(samples_z)
    G.train()  


 
with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# Epoch [    1/  100] | d_loss: 1.3829 | g_loss: 0.7615
# Epoch [    1/  100] | d_loss: 1.6297 | g_loss: 0.4322
# Epoch [    1/  100] | d_loss: 0.9635 | g_loss: 3.3646
# Epoch [    2/  100] | d_loss: 1.4367 | g_loss: 0.7226
# Epoch [    2/  100] | d_loss: 0.9368 | g_loss: 2.2990
# Epoch [    2/  100] | d_loss: 0.8861 | g_loss: 1.6641
# Epoch [    3/  100] | d_loss: 1.1672 | g_loss: 0.9357
# Epoch [    3/  100] | d_loss: 0.9394 | g_loss: 1.6423
# Epoch [    3/  100] | d_loss: 0.9730 | g_loss: 1.2372
# Epoch [    4/  100] | d_loss: 1.0729 | g_loss: 2.9850
# Epoch [    4/  100] | d_loss: 1.1519 | g_loss: 1.1254
# Epoch [    4/  100] | d_loss: 1.3434 | g_loss: 1.0210
# Epoch [    5/  100] | d_loss: 1.2455 | g_loss: 1.2188
# Epoch [    5/  100] | d_loss: 1.1303 | g_loss: 1.4055
# Epoch [    5/  100] | d_loss: 1.3425 | g_loss: 1.0817
# Epoch [    6/  100] | d_loss: 1.4596 | g_loss: 0.8944
# Epoch [    6/  100] | d_loss: 1.1912 | g_loss: 1.1119
# Epoch [    6/  100] | d_loss: 0.9494 | g_loss: 2.3388
# Epoch [    7/  100] | d_loss: 1.1838 | g_loss: 2.1331
# Epoch [    7/  100] | d_loss: 1.2183 | g_loss: 0.9654
# Epoch [    7/  100] | d_loss: 1.2217 | g_loss: 1.2871
# Epoch [    8/  100] | d_loss: 1.1292 | g_loss: 2.0006
# Epoch [    8/  100] | d_loss: 1.2324 | g_loss: 1.0253
# Epoch [    8/  100] | d_loss: 1.2526 | g_loss: 1.2471
# Epoch [    9/  100] | d_loss: 1.1308 | g_loss: 1.9141
# Epoch [    9/  100] | d_loss: 1.2301 | g_loss: 1.4082
# Epoch [    9/  100] | d_loss: 1.3518 | g_loss: 1.0931
# Epoch [   10/  100] | d_loss: 1.1401 | g_loss: 1.5289
# Epoch [   10/  100] | d_loss: 1.1377 | g_loss: 1.6275
# Epoch [   10/  100] | d_loss: 1.1221 | g_loss: 1.2109
# Epoch [   11/  100] | d_loss: 1.3795 | g_loss: 1.2029
# Epoch [   11/  100] | d_loss: 1.1482 | g_loss: 2.0094
# Epoch [   11/  100] | d_loss: 1.1933 | g_loss: 1.2488
# Epoch [   12/  100] | d_loss: 1.2513 | g_loss: 1.2199
# Epoch [   12/  100] | d_loss: 1.2027 | g_loss: 1.1904
# Epoch [   12/  100] | d_loss: 1.2970 | g_loss: 1.1028
# Epoch [   13/  100] | d_loss: 1.1980 | g_loss: 1.0343
# Epoch [   13/  100] | d_loss: 1.0882 | g_loss: 1.3035
# Epoch [   13/  100] | d_loss: 1.2660 | g_loss: 1.3239
# Epoch [   14/  100] | d_loss: 1.3347 | g_loss: 1.0033
# Epoch [   14/  100] | d_loss: 1.3164 | g_loss: 1.3721
# Epoch [   14/  100] | d_loss: 1.2705 | g_loss: 1.0031
# Epoch [   15/  100] | d_loss: 1.3018 | g_loss: 1.0948
# Epoch [   15/  100] | d_loss: 1.2953 | g_loss: 0.8586
# Epoch [   15/  100] | d_loss: 1.3313 | g_loss: 1.0437
# Epoch [   16/  100] | d_loss: 1.3242 | g_loss: 0.9134
# Epoch [   16/  100] | d_loss: 1.1640 | g_loss: 1.0156
# Epoch [   16/  100] | d_loss: 1.2851 | g_loss: 1.0822
# Epoch [   17/  100] | d_loss: 1.3485 | g_loss: 1.1258
# Epoch [   17/  100] | d_loss: 1.3396 | g_loss: 0.9288
# Epoch [   17/  100] | d_loss: 1.2974 | g_loss: 0.8787
# Epoch [   18/  100] | d_loss: 1.3744 | g_loss: 0.8488
# Epoch [   18/  100] | d_loss: 1.2866 | g_loss: 0.8942
# Epoch [   18/  100] | d_loss: 1.1886 | g_loss: 1.0240
# Epoch [   19/  100] | d_loss: 1.2984 | g_loss: 1.2702
# Epoch [   19/  100] | d_loss: 1.3276 | g_loss: 0.8802
# Epoch [   19/  100] | d_loss: 1.3327 | g_loss: 0.9457
# Epoch [   20/  100] | d_loss: 1.2673 | g_loss: 1.2219
# Epoch [   20/  100] | d_loss: 1.1809 | g_loss: 1.1446
# Epoch [   20/  100] | d_loss: 1.3844 | g_loss: 1.0444
# Epoch [   21/  100] | d_loss: 1.2757 | g_loss: 1.0079
# Epoch [   21/  100] | d_loss: 1.3244 | g_loss: 1.1186
# Epoch [   21/  100] | d_loss: 1.2919 | g_loss: 1.2237
# Epoch [   22/  100] | d_loss: 1.2538 | g_loss: 1.0930
# Epoch [   22/  100] | d_loss: 1.2227 | g_loss: 1.1352
# Epoch [   22/  100] | d_loss: 1.3076 | g_loss: 0.9478
# Epoch [   23/  100] | d_loss: 1.3041 | g_loss: 0.9341
# Epoch [   23/  100] | d_loss: 1.2158 | g_loss: 1.1453
# Epoch [   23/  100] | d_loss: 1.3133 | g_loss: 0.8576
# Epoch [   24/  100] | d_loss: 1.3340 | g_loss: 0.8839
# Epoch [   24/  100] | d_loss: 1.2983 | g_loss: 1.0729
# Epoch [   24/  100] | d_loss: 1.3333 | g_loss: 0.9240
# Epoch [   25/  100] | d_loss: 1.3284 | g_loss: 0.7490
# Epoch [   25/  100] | d_loss: 1.2850 | g_loss: 0.8948
# Epoch [   25/  100] | d_loss: 1.4033 | g_loss: 0.9237
# Epoch [   26/  100] | d_loss: 1.2593 | g_loss: 1.1928
# Epoch [   26/  100] | d_loss: 1.2617 | g_loss: 1.0971
# Epoch [   26/  100] | d_loss: 1.3968 | g_loss: 0.9330
# Epoch [   27/  100] | d_loss: 1.4084 | g_loss: 0.8603
# Epoch [   27/  100] | d_loss: 1.1973 | g_loss: 1.0387
# Epoch [   27/  100] | d_loss: 1.3997 | g_loss: 0.8266
# Epoch [   28/  100] | d_loss: 1.2895 | g_loss: 0.9603
# Epoch [   28/  100] | d_loss: 1.2534 | g_loss: 1.0010
# Epoch [   28/  100] | d_loss: 1.2638 | g_loss: 0.9475
# Epoch [   29/  100] | d_loss: 1.3237 | g_loss: 1.1247
# Epoch [   29/  100] | d_loss: 1.2036 | g_loss: 1.0304
# Epoch [   29/  100] | d_loss: 1.2819 | g_loss: 1.1197
# Epoch [   30/  100] | d_loss: 1.2399 | g_loss: 1.1536
# Epoch [   87/  100] | d_loss: 1.3741 | g_loss: 1.1356
# Epoch [   88/  100] | d_loss: 1.1607 | g_loss: 1.3891
# Epoch [   88/  100] | d_loss: 1.1643 | g_loss: 0.9750
# Epoch [   88/  100] | d_loss: 1.3536 | g_loss: 0.8785
# Epoch [   89/  100] | d_loss: 1.2441 | g_loss: 1.4702
# Epoch [   89/  100] | d_loss: 1.1978 | g_loss: 1.3325
# Epoch [   89/  100] | d_loss: 1.3259 | g_loss: 0.9762
# Epoch [   90/  100] | d_loss: 1.3533 | g_loss: 0.8928
# Epoch [   90/  100] | d_loss: 1.1401 | g_loss: 1.0027
# Epoch [   90/  100] | d_loss: 1.2767 | g_loss: 1.0276
# Epoch [   91/  100] | d_loss: 1.3208 | g_loss: 1.1639
# Epoch [   91/  100] | d_loss: 1.2049 | g_loss: 1.3310
# Epoch [   91/  100] | d_loss: 1.3904 | g_loss: 0.9952
# Epoch [   92/  100] | d_loss: 1.3045 | g_loss: 0.9800
# Epoch [   92/  100] | d_loss: 1.2074 | g_loss: 1.0371
# Epoch [   92/  100] | d_loss: 1.3520 | g_loss: 0.9598
# Epoch [   93/  100] | d_loss: 1.3224 | g_loss: 1.0507
# Epoch [   93/  100] | d_loss: 1.3194 | g_loss: 0.8639
# Epoch [   93/  100] | d_loss: 1.2970 | g_loss: 1.0225
# Epoch [   94/  100] | d_loss: 1.2703 | g_loss: 1.5630
# Epoch [   94/  100] | d_loss: 1.3406 | g_loss: 0.8926
# Epoch [   94/  100] | d_loss: 1.4311 | g_loss: 0.9188
# Epoch [   95/  100] | d_loss: 1.2999 | g_loss: 1.2095
# Epoch [   95/  100] | d_loss: 1.2270 | g_loss: 1.0532
# Epoch [   95/  100] | d_loss: 1.3920 | g_loss: 1.0851
# Epoch [   96/  100] | d_loss: 1.4863 | g_loss: 0.8826
# Epoch [   96/  100] | d_loss: 1.1882 | g_loss: 1.1560
# Epoch [   96/  100] | d_loss: 1.2898 | g_loss: 1.0862
# Epoch [   97/  100] | d_loss: 1.2913 | g_loss: 1.3074
# Epoch [   97/  100] | d_loss: 1.2840 | g_loss: 0.9325
# Epoch [   97/  100] | d_loss: 1.3029 | g_loss: 1.0060
# Epoch [   98/  100] | d_loss: 1.2785 | g_loss: 1.0053
# Epoch [   98/  100] | d_loss: 1.2074 | g_loss: 1.0427
# Epoch [   98/  100] | d_loss: 1.4562 | g_loss: 1.1263
# Epoch [   99/  100] | d_loss: 1.2229 | g_loss: 1.3458
# Epoch [   99/  100] | d_loss: 1.2314 | g_loss: 1.1163
# Epoch [   99/  100] | d_loss: 1.3544 | g_loss: 0.9860
# Epoch [  100/  100] | d_loss: 1.2515 | g_loss: 1.3881
# Epoch [  100/  100] | d_loss: 1.2067 | g_loss: 1.0933
# Epoch [  100/  100] | d_loss: 1.3237 | g_loss: 0.9917

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()

# %%
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=5, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach()
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')

# %%
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
view_samples(-1, samples)

# %% [markdown]
# CREATING RANDOM IMAGES USING THE GENERATOR

# %%
sample_size = 20
rand_z = np.random.uniform(-1,1, size=(sample_size,z_size))
rand_z = torch.from_numpy(rand_z).float()

G.eval()
rand_images = G(rand_z)

view_samples(0,[rand_images])
